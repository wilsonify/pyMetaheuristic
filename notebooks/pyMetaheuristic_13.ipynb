# %%
# Created by: Prof. Valdecy Pereira, D.Sc.
# UFF - Universidade Federal Fluminense (Brazil)
# email:  valdecy.pereira@gmail.com
# Lesson: pyMetaheuristic - Moth Flame Optimization
 
# GitHub Repository: <https://github.com/Valdecy>

# %%
# Build Dir
import os
os.chdir('/content')
CODE_DIR = 'code'

# Clone Github Repository
# !git clone https://github.com/Valdecy/pyMetaheuristic.git $CODE_DIR
os.chdir(f'./{CODE_DIR}')
# Out:
# Cloning into 'code'...
# remote: Enumerating objects: 46, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 46 (delta 10), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (46/46), done.

# %%
# Required Libraries
import math
import matplotlib.pyplot as plt
import numpy as np

# MFO
from pyMetaheuristic.moth_flame_optimization.mfa import moth_flame_algorithm

# %%
# Target Function - It can be any function that needs to be minimize, However it has to have only one argument: 'variables_values'. This Argument must be a list of variables.
# For Instance, suppose that our Target Function is the Easom Function (With two variables x1 and x2. Global Minimum f(x1, x2) = -1 for, x1 = 3.14 and x2 = 3.14)

# Target Function: Easom Function
def easom(variables_values = [0, 0]):
    return -math.cos(variables_values[0])*math.cos(variables_values[1])*math.exp(-(variables_values[0] - math.pi)**2 - (variables_values[1] - math.pi)**2)

# %%
# Target Function - Values
x     = np.arange(-1, 7, 0.1)
front = np.zeros((len(x)**2, 3))
count = 0
for j in range (0, len(x)):
    for k in range (0, len(x)):
            front[count, 0] = x[j]
            front[count, 1] = x[k]
            count           = count + 1        
for i in range (0, front.shape[0]):
    front[i, 2] = easom(variables_values = [front[i, 0], front[i, 1]])
front_1       = front[:, 0]
front_2       = front[:, 1]
func_1_values = front[:,-1]

# Target Function - Plot 
plt.style.use('bmh')
fig = plt.figure(figsize = (15, 15))
ax  = fig.add_subplot(111, projection = '3d')
ax.set_xlabel('$x_1$', fontsize = 25, labelpad = 20)
ax.set_ylabel('$x_2$', fontsize = 25, labelpad = 20)
ax.set_zlabel('$f(x_1, x_2)$', fontsize = 25, labelpad = 20)
ax.scatter(front_1, front_2, func_1_values, c = func_1_values, s = 50, alpha = 0.3)
ax.scatter(math.pi, math.pi, -1, c = 'red', s = 100, alpha = 1, edgecolors = 'k', marker = 'o')
ax.text(math.pi-1.0, math.pi-1.5, -1,  '$x_1 = $' + str(round(math.pi, 2)) + ' ; $x_2 = $' + str(round(math.pi, 2)), size = 15, zorder = 1, color = 'k')
ax.text(math.pi+0.5, math.pi-2.5, -1,  '$f(x_1;x_2) = $' + str(-1), size = 15, zorder = 1, color = 'k')
plt.show()

# %%
# MFO - Parameters
ss    = 50
minv  = [-5, -5]
maxv  = [ 5,  5]
iter  = 100
par_b = 1
tgt   = easom

# %%
# MFO - Algorithm
mfo = moth_flame_algorithm(swarm_size = ss, min_values = minv, max_values = maxv, generations = iter, b_constant = par_b, target_function = tgt)
# Out:
# Generation:  0  of  100  f(x) =  -0.06397771248690745
# Generation:  1  of  100  f(x) =  -0.06397771248690745
# Generation:  2  of  100  f(x) =  -0.08278530801395692
# Generation:  3  of  100  f(x) =  -0.8539672291252692
# Generation:  4  of  100  f(x) =  -0.8539672291252692
# Generation:  5  of  100  f(x) =  -0.8539672291252692
# Generation:  6  of  100  f(x) =  -0.8539672291252692
# Generation:  7  of  100  f(x) =  -0.8539672291252692
# Generation:  8  of  100  f(x) =  -0.8539672291252692
# Generation:  9  of  100  f(x) =  -0.8689351962346816
# Generation:  10  of  100  f(x) =  -0.9257162005543047
# Generation:  11  of  100  f(x) =  -0.9957257990207925
# Generation:  12  of  100  f(x) =  -0.9961866462448251
# Generation:  13  of  100  f(x) =  -0.9961866462448251
# Generation:  14  of  100  f(x) =  -0.9961866462448251
# Generation:  15  of  100  f(x) =  -0.9961866462448251
# Generation:  16  of  100  f(x) =  -0.9961866462448251
# Generation:  17  of  100  f(x) =  -0.9994306773807474
# Generation:  18  of  100  f(x) =  -0.9994306773807474
# Generation:  19  of  100  f(x) =  -0.9998836398777031
# Generation:  20  of  100  f(x) =  -0.9999215561313947
# Generation:  21  of  100  f(x) =  -0.9999887152485194
# Generation:  22  of  100  f(x) =  -0.9999994134944767
# Generation:  23  of  100  f(x) =  -0.9999994134944767
# Generation:  24  of  100  f(x) =  -0.9999994134944767
# Generation:  25  of  100  f(x) =  -0.9999994134944767
# Generation:  26  of  100  f(x) =  -0.9999994134944767
# Generation:  27  of  100  f(x) =  -0.9999998250385311
# Generation:  28  of  100  f(x) =  -0.9999999293905752
# Generation:  29  of  100  f(x) =  -0.9999999394810218
# Generation:  30  of  100  f(x) =  -0.9999999557185244
# Generation:  31  of  100  f(x) =  -0.9999999557185244
# Generation:  32  of  100  f(x) =  -0.9999999557185244
# Generation:  33  of  100  f(x) =  -0.9999999632632763
# Generation:  34  of  100  f(x) =  -0.9999999786244632
# Generation:  35  of  100  f(x) =  -0.9999999786244632
# Generation:  36  of  100  f(x) =  -0.9999999966676643
# Generation:  37  of  100  f(x) =  -0.9999999966676643
# Generation:  38  of  100  f(x) =  -0.9999999966676643
# Generation:  39  of  100  f(x) =  -0.9999999977888504
# Generation:  40  of  100  f(x) =  -0.9999999999431691
# Generation:  41  of  100  f(x) =  -0.9999999999431691
# Generation:  42  of  100  f(x) =  -0.9999999999431691
# Generation:  43  of  100  f(x) =  -0.9999999999478977
# Generation:  44  of  100  f(x) =  -0.9999999999965461
# Generation:  45  of  100  f(x) =  -0.9999999999965461
# Generation:  46  of  100  f(x) =  -0.9999999999974173
# Generation:  47  of  100  f(x) =  -0.99999999999834
# Generation:  48  of  100  f(x) =  -0.9999999999998531
# Generation:  49  of  100  f(x) =  -0.9999999999998531
# Generation:  50  of  100  f(x) =  -0.9999999999998785
# Generation:  51  of  100  f(x) =  -0.9999999999999444
# Generation:  52  of  100  f(x) =  -0.9999999999999444
# Generation:  53  of  100  f(x) =  -0.9999999999999546
# Generation:  54  of  100  f(x) =  -0.9999999999999546
# Generation:  55  of  100  f(x) =  -0.9999999999999992
# Generation:  56  of  100  f(x) =  -0.9999999999999992
# Generation:  57  of  100  f(x) =  -0.9999999999999996
# Generation:  58  of  100  f(x) =  -0.9999999999999996
# Generation:  59  of  100  f(x) =  -0.9999999999999996
# Generation:  60  of  100  f(x) =  -0.9999999999999996
# Generation:  61  of  100  f(x) =  -0.9999999999999998
# Generation:  62  of  100  f(x) =  -0.9999999999999999
# Generation:  63  of  100  f(x) =  -1.0
# Generation:  64  of  100  f(x) =  -1.0
# Generation:  65  of  100  f(x) =  -1.0
# Generation:  66  of  100  f(x) =  -1.0
# Generation:  67  of  100  f(x) =  -1.0
# Generation:  68  of  100  f(x) =  -1.0
# Generation:  69  of  100  f(x) =  -1.0
# Generation:  70  of  100  f(x) =  -1.0
# Generation:  71  of  100  f(x) =  -1.0
# Generation:  72  of  100  f(x) =  -1.0
# Generation:  73  of  100  f(x) =  -1.0
# Generation:  74  of  100  f(x) =  -1.0
# Generation:  75  of  100  f(x) =  -1.0
# Generation:  76  of  100  f(x) =  -1.0
# Generation:  77  of  100  f(x) =  -1.0
# Generation:  78  of  100  f(x) =  -1.0
# Generation:  79  of  100  f(x) =  -1.0
# Generation:  80  of  100  f(x) =  -1.0
# Generation:  81  of  100  f(x) =  -1.0
# Generation:  82  of  100  f(x) =  -1.0
# Generation:  83  of  100  f(x) =  -1.0
# Generation:  84  of  100  f(x) =  -1.0
# Generation:  85  of  100  f(x) =  -1.0
# Generation:  86  of  100  f(x) =  -1.0
# Generation:  87  of  100  f(x) =  -1.0
# Generation:  88  of  100  f(x) =  -1.0
# Generation:  89  of  100  f(x) =  -1.0
# Generation:  90  of  100  f(x) =  -1.0
# Generation:  91  of  100  f(x) =  -1.0
# Generation:  92  of  100  f(x) =  -1.0
# Generation:  93  of  100  f(x) =  -1.0
# Generation:  94  of  100  f(x) =  -1.0
# Generation:  95  of  100  f(x) =  -1.0
# Generation:  96  of  100  f(x) =  -1.0
# Generation:  97  of  100  f(x) =  -1.0
# Generation:  98  of  100  f(x) =  -1.0
# Generation:  99  of  100  f(x) =  -1.0
# Generation:  100  of  100  f(x) =  -1.0
# [ 3.14159265  3.14159266 -1.        ]

# %%
# MFO - Solution
variables = mfo[:-1]
minimum   = mfo[ -1]
print('Variables: ', np.around(variables, 4) , ' Minimum Value Found: ', round(minimum, 4) )
# Out:
# Variables:  [3.1416 3.1416]  Minimum Value Found:  -1.0

# %%
# MFO - Plot Solution
plt.style.use('bmh')
fig = plt.figure(figsize = (15, 15))
ax  = fig.add_subplot(111, projection = '3d')
ax.set_xlabel('$x_1$', fontsize = 25, labelpad = 20)
ax.set_ylabel('$x_2$', fontsize = 25, labelpad = 20)
ax.set_zlabel('$f(x_1, x_2)$', fontsize = 25, labelpad = 20)
ax.scatter(front_1, front_2, func_1_values, c = func_1_values, s = 50, alpha = 0.3)
ax.scatter(variables[0], variables[1], minimum, c = 'b', s = 150, alpha = 1, edgecolors = 'k', marker = 's')
ax.text(math.pi-1.0, math.pi-1.5, -1,  '$x_1 = $' + str(round(variables[0], 2)) + ' ; $x_2 = $' + str(round(variables[1], 2)), size = 15, zorder = 1, color = 'k')
ax.text(math.pi+0.5, math.pi-2.5, -1,  '$f(x_1;x_2) = $' + str(round(minimum, 4)), size = 15, zorder = 1, color = 'k')
plt.show()
